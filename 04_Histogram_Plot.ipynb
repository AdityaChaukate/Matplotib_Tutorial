# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random 

x = np.random.randint(10, 60 , (50))
print(x)
# Out:
# [13 20 22 17 15 34 31 37 30 54 10 44 48 54 16 33 31 41 25 53 59 52 18 21
#  54 10 53 17 51 24 35 20 48 53 14 12 40 31 59 54 36 49 54 53 14 35 17 22
#  30 55]

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
plt.hist(no)
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")


plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
plt.hist(no , color = "m" , edgecolor = "b")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")


plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , color = "m" ,bins = l , edgecolor = "b")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")


plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , "auto" , (0,200) , edgecolor = "b")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")


plt.show()
# Out:
# C:\Users\Vinsc\AppData\Local\Temp\ipykernel_13956\3743981140.py:6: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(no , "auto" , (0,200) , edgecolor = "b")

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black",cumulative = -1)
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")


plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black",bottom  = 10)
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")


plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , align = "mid")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , align = "left")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , histtype = "stepfilled")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , histtype = "step")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , histtype = "barstacked")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , histtype = "bar")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" ,orientation = "horizontal")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , rwidth = 0.8)
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , log  = "True")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , label = "Python")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")
plt.legend()

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , label = "Python")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")
plt.axvline(45 , color = 'r')


plt.legend()

plt.show()

# %%
no = [25, 13, 38, 15, 40, 39, 16, 14, 36, 17, 51, 14, 24, 14, 51, 35, 57, 55, 46, 22, 24, 13, 47, 42,
 54, 11, 29, 13, 22, 15, 15, 52, 39, 53, 13, 48, 29, 17, 51, 22, 56, 50, 28, 54, 31, 19, 16, 10,
 53, 13]
l = [10,20,30,40,50,60] 

plt.hist(no , edgecolor = "black", color = "b" , label = "Python")
plt.title("Histogram plot")
plt.xlabel("Python")
plt.ylabel("No")
plt.axvline(45 , color = 'r')


plt.legend()
plt.grid()
plt.show()
